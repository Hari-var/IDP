# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\ShashankTudum\\OneDrive - ValueMomentum, Inc\\Documents\\IDP-LLM\\Files\\Doc_type field configuration.xlsx",sheet_name="doc_types")
print(df)
# Out:
#                       Logical Group                          Document Type  \
# 0     Policy and Coverage Documents                       Policy Documents
# 1                               NaN                Proof of Loss Documents
# 2                               NaN                 Insurance Certificates
# 3        Claim Initiation Documents  First Notice of Loss (FNOL) Documents
# 4                               NaN                Customer Communications
# 5      Investigation and Assessment                  Investigation Reports
# 6                               NaN                        Vehicle reports
# 7                               NaN                      ISO Match Reports
# 8                               NaN                      Property Reports
# 9                               NaN            Fraud Investigation Reports
# 10                              NaN                       Adjuster Reports
# ...
